# %%
from diffusion import train
import argparse

# %%
class Args:
    def __init__(self):
        self.run_name = "DDPM_conditional"
        self.epochs = 300
        self.batch_size = 4
        self.image_size = 64
        self.num_classes = 10
        self.dataset_path = "animal"
        self.device = "cuda"
        self.lr = 3e-4

# %%
args=Args()
train(args)
# Out:
# Loading Weights....
# 09:28:18 - INFO: Starting epoch 1:
# 100%|██████████| 250/250 [00:45<00:00,  5.54it/s, MSE=0.0259]
# 09:29:04 - INFO: Sampling 10 new images....
# 999it [03:19,  5.01it/s]
# 09:32:23 - INFO: Sampling 10 new images....
# 999it [03:19,  5.00it/s]
# 09:35:44 - INFO: Starting epoch 2:
# 100%|██████████| 250/250 [00:41<00:00,  5.95it/s, MSE=0.0194]
# 09:36:26 - INFO: Starting epoch 3:
# 100%|██████████| 250/250 [00:41<00:00,  5.95it/s, MSE=0.000521]
# 09:37:08 - INFO: Starting epoch 4:
# 100%|██████████| 250/250 [00:42<00:00,  5.90it/s, MSE=0.0201]
# 09:37:50 - INFO: Starting epoch 5:
# 100%|██████████| 250/250 [00:42<00:00,  5.91it/s, MSE=0.0221]
# 09:38:33 - INFO: Starting epoch 6:
# 100%|██████████| 250/250 [00:42<00:00,  5.91it/s, MSE=0.00913]
# 09:39:16 - INFO: Starting epoch 7:
# 100%|██████████| 250/250 [00:42<00:00,  5.92it/s, MSE=0.00881]
# 09:39:58 - INFO: Starting epoch 8:
# 100%|██████████| 250/250 [00:42<00:00,  5.94it/s, MSE=0.00256]
# ...
